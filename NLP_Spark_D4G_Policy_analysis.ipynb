# %% [markdown]
# <a href="https://colab.research.google.com/github/decembersnow1234/13_democratiser_sobriete/blob/visualisation_pipeline/NLP_Spark_D4G_Policy_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git version
#!apt-get install git
# Out:
# git version 2.34.1

# %%
# !git clone https://github.com/decembersnow1234/git_repo_sufficiency_policy
# Out:
# Cloning into 'git_repo_sufficiency_policy'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 206 (delta 98), reused 164 (delta 62), pack-reused 0 (from 0)
# Receiving objects: 100% (206/206), 23.65 MiB | 8.33 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
! pip install sparknlp
! pip install -r "/content/git_repo_sufficiency_policy/enhanced/requirements.txt"

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')

# !python /content/git_repo_sufficiency_policy/enhanced/code/run_pipeline.py
# Out:
# 2025-04-23 16:19:23.715938: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745425163.735180    8808 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745425163.741010    8808 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/content/git_repo_sufficiency_policy/enhanced/code/run_pipeline.py", line 92, in <module>
#     main()
#   File "/content/git_repo_sufficiency_policy/enhanced/code/run_pipeline.py", line 68, in main
#     create_default_config()
# ...
